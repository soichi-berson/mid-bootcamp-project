# %%
import numpy as np
import pandas as pd

# %%
#load the data

data = pd.read_excel('../data/Number_of_visits_to_UK.xlsx', engine="openpyxl")

# %%
data
# Out:
#                       Unnamed: 0  Unnamed: 1  Visits (thousands)  \
# 0                            NaN         NaN         2018.000000
# 1                            NaN         NaN                 NaN
# 2                         Canada         NaN          852.244006
# 3                            USA         NaN         4571.476452
# 4                  North America         NaN         5423.720459
# ..                           ...         ...                 ...
# 61                        Mexico         NaN          163.879608
# 62  Other Central & Sth. America         NaN          302.287601
# 63             Rest of the World         NaN            6.109402
# 64               Other Countries         NaN         8166.856464
# 65                   Total World         NaN        40283.202629
#
#       Unnamed: 3    Unnamed: 4   Unnamed: 5    Unnamed: 6  Unnamed: 7 2021-22  \
# 0    2019.000000          2020  2021.000000         2022R         NaN  (000s)
# ...

# %%
data1 = data.iloc[:,:7]
data1
# Out:
#                       Unnamed: 0  Unnamed: 1  Visits (thousands)  \
# 0                            NaN         NaN         2018.000000
# 1                            NaN         NaN                 NaN
# 2                         Canada         NaN          852.244006
# 3                            USA         NaN         4571.476452
# 4                  North America         NaN         5423.720459
# ..                           ...         ...                 ...
# 61                        Mexico         NaN          163.879608
# 62  Other Central & Sth. America         NaN          302.287601
# 63             Rest of the World         NaN            6.109402
# 64               Other Countries         NaN         8166.856464
# 65                   Total World         NaN        40283.202629
#
#       Unnamed: 3    Unnamed: 4   Unnamed: 5    Unnamed: 6
# 0    2019.000000          2020  2021.000000         2022R
# 1            NaN           NaN          NaN           NaN
# ...

# %%
#change columns 
data2 = data1.copy()

new_column_names = {'Unnamed: 0': 'country','Visits (thousands)': '2018', 'Unnamed: 3': '2019', 'Unnamed: 4': '2020', 'Unnamed: 5': '2021','Unnamed: 6': '2022'}
data2 = data2.rename(columns=new_column_names)
data2
# Out:
#                          country  Unnamed: 1          2018          2019  \
# 0                            NaN         NaN   2018.000000   2019.000000
# 1                            NaN         NaN           NaN           NaN
# 2                         Canada         NaN    852.244006    874.060640
# 3                            USA         NaN   4571.476452   4498.754491
# 4                  North America         NaN   5423.720459   5372.815130
# ..                           ...         ...           ...           ...
# 61                        Mexico         NaN    163.879608    166.197819
# 62  Other Central & Sth. America         NaN    302.287601    310.557081
# 63             Rest of the World         NaN      6.109402      1.963070
# 64               Other Countries         NaN   8166.856464   8191.499487
# 65                   Total World         NaN  40283.202629  40857.447996
#
#             2020         2021          2022
# 0           2020  2021.000000         2022R
# ...

# %%
#remove 'unnamed: 1'
data3 = data2.drop('Unnamed: 1', axis =1)
data3
# Out:
#                          country          2018          2019          2020  \
# 0                            NaN   2018.000000   2019.000000          2020
# 1                            NaN           NaN           NaN           NaN
# 2                         Canada    852.244006    874.060640          -
# 3                            USA   4571.476452   4498.754491          -
# 4                  North America   5423.720459   5372.815130   1170.790477
# ..                           ...           ...           ...           ...
# 61                        Mexico    163.879608    166.197819          -
# 62  Other Central & Sth. America    302.287601    310.557081          -
# 63             Rest of the World      6.109402      1.963070          -
# 64               Other Countries   8166.856464   8191.499487   1941.924295
# 65                   Total World  40283.202629  40857.447996  11100.507124
#
#            2021          2022
# 0   2021.000000         2022R
# ...

# %%
#remove index 0 and 1 
data4 = data3.iloc[2:,:]
data4
# Out:
#                          country          2018          2019          2020  \
# 2                         Canada    852.244006    874.060640          -
# 3                            USA   4571.476452   4498.754491          -
# 4                  North America   5423.720459   5372.815130   1170.790477
# 5                        Austria    327.289461    342.130139          -
# 6                        Belgium   1096.778896   1134.973111          -
# ..                           ...           ...           ...           ...
# 61                        Mexico    163.879608    166.197819          -
# 62  Other Central & Sth. America    302.287601    310.557081          -
# 63             Rest of the World      6.109402      1.963070          -
# 64               Other Countries   8166.856464   8191.499487   1941.924295
# 65                   Total World  40283.202629  40857.447996  11100.507124
#
#            2021          2022
# 2    128.184612    896.646943
# ...

# %%
# %load ../src/function.py
import pandas as pd

def remove_region(df:pd.DataFrame) -> pd.DataFrame:
	'''
	This function removes enexpected values(region) of the column: 'country' but only' total world' and 
	something of 'other--- ' are remained.

	Input:pd.DataFrame

	Output:pd.DataFrame  


	''' 
	df2 = df.copy()

	remove_regions = {'North America', 'North America', '- of which EU', '- of which EU15', '- of which EU Oth', 'Europe'}

	#for i in len(df):
	#	if df2['country'] in remove_regions:
	#		df2. 
	df2 = df2[~df2['country'].isin(remove_regions )]





	return df2




#if __name__ == "__main__" :
	
#	 remove_region()

# %%
# %run -i ../src/function.py

data5 = data4.copy()
data6 = remove_region(data5)
data6
# Out:
#                          country          2018          2019          2020  \
# 2                         Canada    852.244006    874.060640          -
# 3                            USA   4571.476452   4498.754491          -
# 5                        Austria    327.289461    342.130139          -
# 6                        Belgium   1096.778896   1134.973111          -
# 7                       Bulgaria    232.804800    235.485153          -
# 8                 Czech Republic    360.292490    413.526195          -
# 9                         Cyprus    108.084657    128.453580          -
# 10                       Denmark    614.176524    691.394210          -
# 11                       Finland    188.279552    214.525742          -
# 12                        France   3591.885263   3560.516774          -
# 13                       Germany   3170.208595   3232.912268          -
# 14                        Greece    223.120404    250.185039          -
# ...

# %%
# replace '-' into null values 
data6.dtypes
# Out:
# country     object
# 2018       float64
# 2019       float64
# 2020        object
# 2021       float64
# 2022        object
# dtype: object

# %%
# the column '2020' is changed into null values and float values. 
# first change the index 
data8 = data6.reset_index(drop=True)
data8
# Out:
#                          country          2018          2019          2020  \
# 0                         Canada    852.244006    874.060640          -
# 1                            USA   4571.476452   4498.754491          -
# 2                        Austria    327.289461    342.130139          -
# 3                        Belgium   1096.778896   1134.973111          -
# 4                       Bulgaria    232.804800    235.485153          -
# 5                 Czech Republic    360.292490    413.526195          -
# 6                         Cyprus    108.084657    128.453580          -
# 7                        Denmark    614.176524    691.394210          -
# 8                        Finland    188.279552    214.525742          -
# 9                         France   3591.885263   3560.516774          -
# 10                       Germany   3170.208595   3232.912268          -
# 11                        Greece    223.120404    250.185039          -
# ...

# %%
data8.loc[0:56,'2020'] = np.nan
data8
# Out:
#                          country          2018          2019          2020  \
# 0                         Canada    852.244006    874.060640           NaN
# 1                            USA   4571.476452   4498.754491           NaN
# 2                        Austria    327.289461    342.130139           NaN
# 3                        Belgium   1096.778896   1134.973111           NaN
# 4                       Bulgaria    232.804800    235.485153           NaN
# 5                 Czech Republic    360.292490    413.526195           NaN
# 6                         Cyprus    108.084657    128.453580           NaN
# 7                        Denmark    614.176524    691.394210           NaN
# 8                        Finland    188.279552    214.525742           NaN
# 9                         France   3591.885263   3560.516774           NaN
# 10                       Germany   3170.208595   3232.912268           NaN
# ...

# %%
# change the data type of '2022' into float64
data8['2022'] = data8['2022'].astype('float64')
data8.dtypes
# Out:
# country     object
# 2018       float64
# 2019       float64
# 2020       float64
# 2021       float64
# 2022       float64
# dtype: object

# %% [markdown]
# In the process of importing the Excel file, all values were unexpectedly changed. For example, the value of Canada (2018) is 852, but it says 852.244006. So, it has to be rounded.
# In addition, the unit is 'thousands. As the small amount of number is better to look at, the value will not be multiplied by 1000.

# %%
data9 = data8.copy()
data10 = data9.round()
data10
# Out:
#                          country     2018     2019     2020    2021     2022
# 0                         Canada    852.0    874.0      NaN   128.0    897.0
# 1                            USA   4571.0   4499.0      NaN   663.0   4587.0
# 2                        Austria    327.0    342.0      NaN    56.0    288.0
# 3                        Belgium   1097.0   1135.0      NaN   159.0    679.0
# 4                       Bulgaria    233.0    235.0      NaN    56.0    183.0
# 5                 Czech Republic    360.0    414.0      NaN    55.0    276.0
# 6                         Cyprus    108.0    128.0      NaN    42.0    123.0
# 7                        Denmark    614.0    691.0      NaN   102.0    566.0
# 8                        Finland    188.0    215.0      NaN    17.0    169.0
# 9                         France   3592.0   3561.0      NaN   677.0   2830.0
# 10                       Germany   3170.0   3233.0      NaN   390.0   2233.0
# ...

# %%
# The data type apart from the column'country' changed into 'int64'.
data11 = data10.copy()
data12 = data11.astype('int64', errors='ignore')
data12
# Out:
#                          country   2018   2019     2020  2021   2022
# 0                         Canada    852    874      NaN   128    897
# 1                            USA   4571   4499      NaN   663   4587
# 2                        Austria    327    342      NaN    56    288
# 3                        Belgium   1097   1135      NaN   159    679
# 4                       Bulgaria    233    235      NaN    56    183
# 5                 Czech Republic    360    414      NaN    55    276
# 6                         Cyprus    108    128      NaN    42    123
# 7                        Denmark    614    691      NaN   102    566
# 8                        Finland    188    215      NaN    17    169
# 9                         France   3592   3561      NaN   677   2830
# 10                       Germany   3170   3233      NaN   390   2233
# 11                        Greece    223    250      NaN    72    185
# 12                       Hungary    372    334      NaN    58    255
# ...

# %% [markdown]
# The values of '2020' have null values, so the int values are converted into float values.

# %%
data12
# Out:
#                          country   2018   2019     2020  2021   2022
# 0                         Canada    852    874      NaN   128    897
# 1                            USA   4571   4499      NaN   663   4587
# 2                        Austria    327    342      NaN    56    288
# 3                        Belgium   1097   1135      NaN   159    679
# 4                       Bulgaria    233    235      NaN    56    183
# 5                 Czech Republic    360    414      NaN    55    276
# 6                         Cyprus    108    128      NaN    42    123
# 7                        Denmark    614    691      NaN   102    566
# 8                        Finland    188    215      NaN    17    169
# 9                         France   3592   3561      NaN   677   2830
# 10                       Germany   3170   3233      NaN   390   2233
# 11                        Greece    223    250      NaN    72    185
# 12                       Hungary    372    334      NaN    58    255
# ...

# %%
# save the data
data12.to_csv('../data/cleaned_number_of_visitors.csv', index=False)
